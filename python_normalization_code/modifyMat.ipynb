# %%
from simulation import Simulation
import numpy as np
import time

# %%
startT = time.time()
sim = Simulation('/scratch/jkopsick/git_09_05_23/CARLsim6/.build/projects/ca3_full_net_lognormalI_09_05_23_assem_75_ov_five_pct/network40p.dat', debug=True)
endT = time.time()
endT-startT
# Out:
# LOADED HEADER
# LOADED GROUP: b'CA3_QuadD_LM'
# LOADED GROUP: b'CA3_Axo_Axonic'
# ...

# %%
startT = time.time()
pcWeight = []
for syn in sim.synapses[0][:]:
    if syn.connId == 50:
        pcWeight.append(syn.weight)
endT = time.time()
len(pcWeight)
endT-startT
# Out:
# 31.409522533416748

# %%
meanPCWeight = np.mean(pcWeight)
meanPCWeight
# Out:
# 0.6762655087219354

# %%
maxPCWeight = np.max(pcWeight)
maxPCWeight
# Out:
# 80.0

# %%
minPCWeight = np.min(pcWeight)
minPCWeight
# Out:
# 0.625

# %%
startT = time.time()
for syn in sim.synapses[0][:]:
    if syn.connId == 50:
        syn.weight = syn.weight/meanPCWeight*0.625
endT = time.time()
endT-startT
# Out:
# 54.378653049468994

# %%
startT = time.time()
sim.save('/scratch/jkopsick/git_09_05_23/CARLsim6/.build/projects/ca3_full_net_lognormalI_09_05_23_assem_75_ov_five_pct/network40p_ov_five_pct_assem75_divnorm.dat',debug=True)
endT = time.time()
endT-startT
# Out:
# WROTE HEADER
# WROTE GROUP: b'CA3_QuadD_LM'
# WROTE GROUP: b'CA3_Axo_Axonic'
# ...
